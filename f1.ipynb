# %%
s

# %%
from fastapi import FastAPI

app = FastAPI()

# Simple root endpoint (we already had this)
@app.get("/")
def read_root():
    return {"message": "Hello World from Mohamed! 🚀 Cairo 2026"}

# New: Path parameter example
# The {name} part becomes a variable we can use
@app.get("/hello/{name}")
def say_hello(name: str):
    return {"greeting": f"Hello, {name}! Welcome to FastAPI 🌟"}

# Another path parameter example - with type (int)
@app.get("/items/{item_id}")
def read_item(item_id: int):
    return {"item_id": item_id, "description": "This is item number " + str(item_id)}

# Bonus: What happens if someone sends wrong type?
# Try /items/abc in browser → FastAPI gives nice error automatically!

# %%
pip install fastapi uvicorn
# Out:
# Requirement already satisfied: fastapi in ./FastApi/lib/python3.12/site-packages (0.128.1)
# Requirement already satisfied: uvicorn in ./FastApi/lib/python3.12/site-packages (0.40.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in ./FastApi/lib/python3.12/site-packages (from fastapi) (0.50.0)
# Requirement already satisfied: pydantic>=2.7.0 in ./FastApi/lib/python3.12/site-packages (from fastapi) (2.12.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in ./FastApi/lib/python3.12/site-packages (from fastapi) (4.15.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in ./FastApi/lib/python3.12/site-packages (from fastapi) (0.0.4)
# Requirement already satisfied: click>=7.0 in ./FastApi/lib/python3.12/site-packages (from uvicorn) (8.3.1)
# Requirement already satisfied: h11>=0.8 in ./FastApi/lib/python3.12/site-packages (from uvicorn) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in ./FastApi/lib/python3.12/site-packages (from pydantic>=2.7.0->fastapi) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in ./FastApi/lib/python3.12/site-packages (from pydantic>=2.7.0->fastapi) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in ./FastApi/lib/python3.12/site-packages (from pydantic>=2.7.0->fastapi) (0.4.2)
# Requirement already satisfied: anyio<5,>=3.6.2 in ./FastApi/lib/python3.12/site-packages (from starlette<0.51.0,>=0.40.0->fastapi) (4.12.1)
# Requirement already satisfied: idna>=2.8 in ./FastApi/lib/python3.12/site-packages (from anyio<5,>=3.6.2->starlette<0.51.0,>=0.40.0->fastapi) (3.11)
# Note: you may need to restart the kernel to use updated packages.

# %%
uvicorn.run(app, host="127.0.0.1", port=8000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 uvicorn.run(app, host="127.0.0.1", port=8000)
#
# NameError: name 'uvicorn' is not defined
